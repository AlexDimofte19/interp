# %%
# !ls /workspace/reasoning_theatre/trajectories_train_single_step_probs/plots
# Out:
# 10_first_correct_no_reasoning_heatmap.png
# 11_committed_before_full_reasoning.png
# 12_convinced_before_full_heatmap.png
# 13_first_correct_before_full_heatmap.png
# 1_fraction_first_correct_vs_convinced.png
# 2_sentence_accuracy_per_size.png
# 3_answer_prob_around_convinced.png
# 4_answer_prob_around_first_correct.png
# 5_first_correct_no_reasoning_per_size.png
# 6_convinced_no_reasoning_per_size.png
# 7_convinced_fraction_heatmap.png
# 8_first_correct_fraction_heatmap.png
# 9_convinced_no_reasoning_heatmap.png

# %%
# Source - https://stackoverflow.com/a/11855133
# Posted by zach, modified by community. See post 'Timeline' for change history
# Retrieved 2026-08-28, License - CC BY-SA 3.0

from IPython.display import Image

root = "/workspace/reasoning_theatre/trajectories_train_single_step_probs/plots"
img = "10_first_correct_no_reasoning_heatmap.png"
Image(filename=root + "/" + img)
